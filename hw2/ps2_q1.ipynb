# %%
import numpy as np
import matplotlib.pyplot as plt

a_set = [0.253, 0.263, 0.27, 0.279, 0.288, 0.295, 0.308]
a = np.array(a_set)

b_set = [0,0,0.299, 0.305, 0.312, 0.32, 0.33]
b = np.array(b_set)

alpha = [40, 100, 200, 400, 1000, 2000, 4000]
alp = np.array(alpha)

c = np.array([0.338, 0.345, 0.348, 0.35, 0.357, 0.368])
c_a = np.sqrt(np.array([40, 100, 200, 400, 1000, 2000]))

plt.plot(a, alp ** 2)
plt.title("A: a^2")
plt.show()

# %%
plt.plot(a, np.sqrt(alp))
plt.title("A: a^-1/2")
plt.show()

# %%
b_a = np.array([200, 400, 1000, 2000, 4000])
b = np.array([0.299,.305,.312,.32,.33])
plt.plot(b, b_a ** 2)
plt.title("B: a2")
plt.show()

# %%
plt.plot(b, np.sqrt(b_a))
plt.title("B: a^-1/2")
plt.show()

# %%
c = np.array([0.338, 0.345, 0.348, 0.35, 0.357, 0.368])
c_a = np.array([40, 100, 200, 400, 1000, 2000])
plt.plot(c, c_a ** 2)
plt.title("C: a^2")
plt.show()

# %%
plt.plot(c, np.sqrt(c_a))
plt.title("C: a^-1/2")
plt.show()

# %%
plt.plot(c, c_a ** 2)
plt.title("C: a^2")
plt.show()

# %%
c_a ** 2
# Out:
# array([   1600,   10000,   40000,  160000, 1000000, 4000000])

# %%
d = np.array([0.37, 0.381,0.388,0.395,.401,.415,.433])

# %%
plt.plot(d, alp ** 2)
plt.title("D: a^2")
plt.show()

# %%
plt.plot(d, np.sqrt(alp))
plt.title("D: a^-1/2")
plt.show()
